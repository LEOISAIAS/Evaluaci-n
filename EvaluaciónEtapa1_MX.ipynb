# %% [markdown]
# <a href="https://colab.research.google.com/github/LEOISAIAS/Evaluaci-n/blob/main/Evaluaci%C3%B3nEtapa1_MX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **EVALUACIÓN**
#
# ETAPA1/DATASET *MX*
# ## Leonardo Isaías Guevara Pioquinto
#
# ###***A01275327***

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#EUA = pd.read_csv("California_EUA.csv", encoding= 'unicode_escape')
#EUA

# %%
#ESP = pd.read_csv("Girona_España.csv", encoding= 'unicode_escape')
#ESP

# %%
MX = pd.read_csv("DF_Mexico.csv")
MX

# %% [markdown]
# #***MÉXICO***

# %%
#Verificamos información del DataFrame
MX.info()

# %%
#Corroboramos valores nulos
valores_nulos=MX.isnull().sum()
valores_nulos

# %%
#Corroboramos valores nulos
valores_nulos=MX.isnull().sum()
valores_nulos.to_csv("valores_nulosMX.csv")
from google.colab import files 

files.download("valores_nulosMX.csv")

# %% [markdown]
# # **PROCEDIMIENTO PARA ELIMINAR VALORES NULOS EN DATAFRAME**

# %%
#Reemplazamos valores nulos del dataframe con "0"
data =MX.fillna(0) 
data

# %% [markdown]
# Se utilizó el método de sustitución de
# valores nulos con 0 con el fin de tener mejor apreciación y manipulación de los datos, de igual forma comparar la eficacia de rellenar datos un con un valor en específico.
# Reemplazar los valores nulos con ceros puede ser útil en varios escenarios. Los valores nulos pueden ser problemáticos en análisis de datos y cálculos posteriores, ya que pueden generar errores o distorsionar los resultados. Al remplazar los valores nulos con ceros, se puede facilitar el procesamiento y análisis de los datos, especialmente si los ceros son una representación razonable de la ausencia de información o una categoría distinta.
# Sin embargo, es importante tener en cuenta que el reemplazo de valores nulos con ceros no siempre es la mejor estrategia. Dependerá del contexto y del significado de los valores nulos en los datos. En algunos casos, puede ser más apropiado utilizar otro valor de reemplazo o aplicar técnicas de imputación más avanzadas para estimar los valores faltantes basándose en otros datos disponibles.

# %%
#Corroboramos valores nulos del dataframe
valores_nulos=MX.isnull().sum()
valores_nulos

# %% [markdown]
# : Esta línea de código utiliza el método isnull() de Pandas para verificar qué valores del DataFrame "MX" son nulos. Luego, se aplica el método sum() para calcular la suma de los valores nulos en cada columna del DataFrame. El resultado se asigna a una nueva variable llamada "valores_nulos".Verificar la presencia de valores nulos en un DataFrame es un paso importante en el análisis de datos. Los valores nulos pueden representar información faltante o inconsistencias en los datos, y es esencial identificarlos para poder tomar decisiones adecuadas en el procesamiento y análisis posterior.

# %%
#Reemplazamos valores nulos del dataframe con "mean"
data2=MX.copy()
data2=data2.fillna(round(MX.mean(),1))
data2

# %% [markdown]
# Esta línea de código crea una copia del DataFrame "MX" y la asigna a una nueva variable llamada "data2". Esto se hace para evitar modificar el DataFrame original y para trabajar con una copia independiente.
#
# data2 = data2.fillna(round(MX.mean(),1)): Esta línea de código utiliza el método fillna() de Pandas para reemplazar los valores nulos del DataFrame "data2" con la media de cada columna, redondeada a un decimal. Para ello, se utiliza el método mean() de Pandas para calcular la media de cada columna del DataFrame "MX". Luego, se utiliza la función round() para redondear el valor de la media a un decimal. Finalmente, se asigna el resultado a la variable "data2".
# Reemplazar los valores nulos con la media de cada columna es una estrategia común en el procesamiento de datos. Esta estrategia ayuda a mantener la distribución de los datos y puede mejorar la precisión de los análisis posteriores.

# %%
#Corroboramos valores nulos del dataframe
valores_nulos=data2.isnull().sum()
valores_nulos

# %%
#Realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize =(15, 8))
data2.plot(kind='box', vert=False)
plt.title("Valores Atípicos del Dataframe")
plt.show() #dibujamos el diagrama

# %% [markdown]
# # **PROCEDIMIENTO "DESVIACIÓN ESTÁNDAR" PARA ELIMINAR OUTLIERS EN DATAFRAME**

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=data2
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# <ipython-input-16-4c899ed993c2>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Superior= y.mean() + 3*y.std()
# <ipython-input-16-4c899ed993c2>:3: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Superior= y.mean() + 3*y.std()
# ...

# %% [markdown]
# El código proporcionado tiene como objetivo calcular los límites superiores e inferiores permitidos utilizando la desviación estándar en el DataFrame "data2"

# %%
#Encontramos Ouliers del Dataframe
outliers= data2[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
# <ipython-input-17-b3686d19c4d6>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outliers= data2[(y>Limite_Superior)|(y<Limite_Inferior)]
#        id listing_url  scrape_id last_scraped source name description  \
# 0     NaN         NaN        NaN          NaN    NaN  NaN         NaN
# 1     NaN         NaN        NaN          NaN    NaN  NaN         NaN
# 2     NaN         NaN        NaN          NaN    NaN  NaN         NaN
# 3     NaN         NaN        NaN          NaN    NaN  NaN         NaN
# 4     NaN         NaN        NaN          NaN    NaN  NaN         NaN
# ...    ..         ...        ...          ...    ...  ...         ...
# 24219 NaN         NaN        NaN          NaN    NaN  NaN         NaN
# 24220 NaN         NaN        NaN          NaN    NaN  NaN         NaN
# ...

# %%
#Obtenemos datos y los outliers se convierten en nulos en el DataFrame
data3= data2[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data3
# Out:
# <ipython-input-18-1e038dbc0c4a>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   data3= data2[(y<=Limite_Superior)&(y>=Limite_Inferior)]
#                        id listing_url       scrape_id last_scraped source  \
# 0                 2056638         NaN  20230329041210          NaN    NaN
# 1                 2072354         NaN  20230329041210          NaN    NaN
# 2                  696037         NaN  20230329041210          NaN    NaN
# 3                   35797         NaN  20230329041210          NaN    NaN
# 4                   44616         NaN  20230329041210          NaN    NaN
# ...                   ...         ...             ...          ...    ...
# 24219  853923589855678923         NaN  20230329041210          NaN    NaN
# ...

# %%
#Eliminamos columnas innecesarias
data= data.drop(['neighbourhood_group_cleansed', 'bathrooms', 'calendar_updated'], axis=1)
data
# Out:
#                        id                                      listing_url  \
# 0                 2056638             https://www.airbnb.com/rooms/2056638
# 1                 2072354             https://www.airbnb.com/rooms/2072354
# 2                  696037              https://www.airbnb.com/rooms/696037
# 3                   35797               https://www.airbnb.com/rooms/35797
# 4                   44616               https://www.airbnb.com/rooms/44616
# ...                   ...                                              ...
# 24219  853923589855678923  https://www.airbnb.com/rooms/853923589855678923
# 24220  853966732274073000  https://www.airbnb.com/rooms/853966732274073000
# 24221  854225071295768399  https://www.airbnb.com/rooms/854225071295768399
# 24222  854247693069190865  https://www.airbnb.com/rooms/854247693069190865
# 24223  854260329845513725  https://www.airbnb.com/rooms/854260329845513725
#
#             scrape_id last_scraped       source  \
# ...

# %%
#Corroboramos valores nulos del dataframe4
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# id                                              0
# listing_url                                     0
# scrape_id                                       0
# last_scraped                                    0
# source                                          0
#                                                ..
# calculated_host_listings_count                  0
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# calculated_host_listings_count_shared_rooms     0
# reviews_per_month                               0
# Length: 72, dtype: int64

# %%
#Reemplazamos valores nulos del dataframe con "0"
data_clean =data.fillna(0) 
data_clean
# Out:
#                        id                                      listing_url  \
# 0                 2056638             https://www.airbnb.com/rooms/2056638
# 1                 2072354             https://www.airbnb.com/rooms/2072354
# 2                  696037              https://www.airbnb.com/rooms/696037
# 3                   35797               https://www.airbnb.com/rooms/35797
# 4                   44616               https://www.airbnb.com/rooms/44616
# ...                   ...                                              ...
# 24219  853923589855678923  https://www.airbnb.com/rooms/853923589855678923
# 24220  853966732274073000  https://www.airbnb.com/rooms/853966732274073000
# 24221  854225071295768399  https://www.airbnb.com/rooms/854225071295768399
# 24222  854247693069190865  https://www.airbnb.com/rooms/854247693069190865
# 24223  854260329845513725  https://www.airbnb.com/rooms/854260329845513725
#
#             scrape_id last_scraped       source  \
# ...

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data_clean.isnull().sum()
valores_nulos
# Out:
# id                                              0
# listing_url                                     0
# scrape_id                                       0
# last_scraped                                    0
# source                                          0
#                                                ..
# calculated_host_listings_count                  0
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# calculated_host_listings_count_shared_rooms     0
# reviews_per_month                               0
# Length: 72, dtype: int64

# %%
#Convertir DataFrame a CSV
data_clean.to_csv("Datos_limpios_MX.csv")
#descargar archivo filtrado en csv
from google.colab import files 
  
  
files.download("Datos_limpios_MX.csv")
